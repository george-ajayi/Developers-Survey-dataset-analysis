# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# *   Identify duplicate values in the dataset.
#
# *   Remove duplicate values from the dataset.
#
# *   Identify missing values in the dataset.
#
# *   Impute the missing values in the dataset.
#
# *   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("m1_survey_data.csv")
df.head(2)
# Out:
#    Respondent                      MainBranch Hobbyist  \
# 0           4  I am a developer by profession       No
# 1           9  I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1  Once a month or more often
#
#                                           OpenSource          Employment  \
# 0  The quality of OSS and closed source software ...  Employed full-time
# 1  The quality of OSS and closed source software ...  Employed full-time
#
#          Country Student                                            EdLevel  \
# 0  United States      No           Bachelor’s degree (BA, BS, B.Eng., etc.)
# 1    New Zealand      No  Some college/university study without earning ...
#
#                                       UndergradMajor  ...  \
# 0  Computer science, computer engineering, or sof...  ...
# 1  Computer science, computer engineering, or sof...  ...
#
#                              WelcomeChange  \
# ...

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
# Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
duplicates=df[df.duplicated(subset=['Respondent'])].sort_values('Respondent')
len(duplicates)
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
without_duplicates=df.drop_duplicates()
without_duplicates
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
without_duplicates[without_duplicates.duplicated(subset=['Respondent'])]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
data=without_duplicates.copy()
d=pd.DataFrame(data.isnull().sum()).reset_index()
d.rename(columns={0:'no_null_values','index':'col'},inplace=True)
d[d.no_null_values !=0]
# Out:
#                col  no_null_values
# 4       OpenSource              81
# 7          Student              51
# 8          EdLevel             112
# 9   UndergradMajor             737
# 10        EduOther             164
# ..             ...             ...
# 80       Sexuality             542
# 81       Ethnicity             675
# 82      Dependents             140
# 83    SurveyLength              19
# 84      SurveyEase              14
#
# [73 rows x 2 columns]

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
data.WorkLoc.isna().sum()
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
data.WorkLoc.value_counts()
# Out:
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %% [markdown]
# <h5>The most frequent in the WorkLoc column is the Office

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes 
data.WorkLoc.fillna('Office',inplace=True)

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
data.WorkLoc.isna().sum()
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
data.CompFreq.unique()
# Out:
# array(['Yearly', 'Monthly', 'Weekly', nan], dtype=object)

# %%
# finding out the number of null values in the CompFreq column
data.CompFreq.isna().sum()
# Out:
# 206

# %%
# dropping the null values in the CompFreq column
data=data.dropna(subset=['CompFreq'])

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
#
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal,
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year),
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)

# %%
# your code goes here
def normalize(x,compfreq):
   operation={'Yearly':1,'Monthly':12,'Weekly':52}
   return x * operation[compfreq]
data['NormalizedAnnualCompensation']=data.apply(lambda x: normalize(x['CompTotal'],x['CompFreq']),axis=1)
data[['NormalizedAnnualCompensation','CompFreq','CompTotal','MainBranch']].head()
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15032\1885826470.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['NormalizedAnnualCompensation']=data.apply(lambda x: normalize(x['CompTotal'],x['CompFreq']),axis=1)
#    NormalizedAnnualCompensation CompFreq  CompTotal  \
# 0                       61000.0   Yearly    61000.0
# 1                      138000.0   Yearly   138000.0
# 2                       90000.0   Yearly    90000.0
# 3                      348000.0  Monthly    29000.0
# 4                       90000.0   Yearly    90000.0
#
#                        MainBranch
# 0  I am a developer by profession
# 1  I am a developer by profession
# 2  I am a developer by profession
# 3  I am a developer by profession
# ...

# %%
data.NormalizedAnnualCompensation.describe()
# Out:
# count    1.058900e+04
# mean     6.133295e+06
# std      9.838157e+07
# min      0.000000e+00
# 25%      5.200000e+04
# 50%      1.000000e+05
# 75%      3.600000e+05
# max      8.400000e+09
# Name: NormalizedAnnualCompensation, dtype: float64

# %%
data.to_('survey_data.xlsx',index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\User\Downloads\M2DataWrangling-lab.ipynb Cell 49 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/User/Downloads/M2DataWrangling-lab.ipynb#X66sZmlsZQ%3D%3D?line=0'>1</a> data.to_('survey_data.xlsx',index=False)
#
# File c:\Users\User\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'to_'

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
# Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork21426264-2022-01-01&cm_mmc=Email_Newsletter-\_-Developer_Ed%2BTech-\_-WW_WW-\_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
